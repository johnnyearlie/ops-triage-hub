# %%
import sys
print(sys.version)
# Out:
# 3.14.0 (main, Oct  7 2025, 09:34:52) [Clang 17.0.0 (clang-1700.0.13.3)]

# %%
# sys was imported in a previous cell
print(sys.version)
# Out:
# 3.14.0 (main, Oct  7 2025, 09:34:52) [Clang 17.0.0 (clang-1700.0.13.3)]

# %%
name = "Johnny"
course = "AI Engineering"
print (f"Helllo,   {name}! Welcome to {course} .")
numbers = [1,  2,  3,  4,  5,]

for n in numbers:
    squares.append(n ** 2)
                       
 squares
                   
def greet (name):
    return   f"Nice to see you,   {name}.  You're ready for this."
greet("Johnny")
# Out:
#   Cell In[17], line 12
#     return   f"Nice to see you,   {name}.  You're ready for this."
#     ^
# IndentationError: expected an indented block after function definition on line 11

# %%
# Out:
# Hello, Johnny! Welcome to AI Engineering.
# "Nice to see you, Johnny. You're ready for this."
